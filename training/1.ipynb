# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd /content/yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# ...

# %%
# !pip install ultralytics

# %%
import os
project_folder = "/content/drive/MyDrive/major_project"
models = {
    "YOLOv5": os.path.join(project_folder, "v5best.pt"),
    "YOLOv8": os.path.join(project_folder, "v8best.pt"),
    "YOLOv11": os.path.join(project_folder, "v11best.pt"),
    "YOLOv26": os.path.join(project_folder, "v26best.pt")
}
dataset_yaml = os.path.join(project_folder, "military_dataset.yaml")
test_image = os.path.join(project_folder, "000006.jpg")

# %%
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/major_project/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "military"
# Out:
# ref                                                      title                                                      size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  --------------------------------------------------  -----------  --------------------------  -------------  ---------  ---------------
# a2015003713/militaryaircraftdetectiondataset             Military Aircraft Detection Dataset                 11843276548  2026-02-20 08:53:34.203000          18625        281  0.7058824
# nitinsss/military-expenditure-of-countries-19602019      Military Spending of Countries (1960-2019)                55911  2019-10-10 12:17:37.773000          12442        262  1.0
# khlaifiabilel/military-aircraft-recognition-dataset      Military Aircraft Recognition dataset                1208088860  2022-09-21 15:43:55.673000           5826         70  0.875
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/major_project/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !ls /content/major_project/
# Out:
# military_dataset.yaml  military_object_dataset

# %%
# !ls /content/major_project/military_object_dataset/
# Out:
# dataset.md  military_dataset.yaml  test  train	val

# %%
# !ls /content/major_project/military_object_dataset/train/images
# Out:
# 000065.jpg  004300.jpg	008216.jpg  012886.jpg	017605.jpg  021461.jpg
# 000066.jpg  004301.jpg	008217.jpg  012887.jpg	017606.jpg  021462.jpg
# 000067.jpg  004302.jpg	008218.jpg  012888.jpg	017607.jpg  021463.jpg
# 000068.jpg  004303.jpg	008219.jpg  012889.jpg	017608.jpg  021464.jpg
# 000069.jpg  004304.jpg	008220.jpg  012890.jpg	017609.jpg  021465.jpg
# 000070.jpg  004305.jpg	008221.jpg  012891.jpg	017610.jpg  021466.jpg
# 000071.jpg  004306.jpg	008222.jpg  012892.jpg	017611.jpg  021467.jpg
# 000072.jpg  004307.jpg	008223.jpg  012893.jpg	017612.jpg  021468.jpg
# 000073.jpg  004308.jpg	008224.jpg  012894.jpg	017613.jpg  021469.jpg
# 000074.jpg  004309.jpg	008225.jpg  012895.jpg	017614.jpg  021470.jpg
# 000075.jpg  004310.jpg	008226.jpg  012896.jpg	017615.jpg  021471.jpg
# 000076.jpg  004311.jpg	008227.jpg  012897.jpg	017616.jpg  021472.jpg
# 000077.jpg  004312.jpg	008228.jpg  012898.jpg	017617.jpg  021473.jpg
# 000078.jpg  004313.jpg	008229.jpg  012899.jpg	017618.jpg  021474.jpg
# ...

# %%
# !cat /content/drive/MyDrive/major_project/military_dataset.yaml
# Out:
# path: /kaggle/input/military-assets-dataset-12-classes-yolo8-format/military_object_dataset
# test: test/images
# train: train/images
# val: val/images
#
# names:
#   0: camouflage_soldier
#   1: weapon
#   2: military_tank
#   3: military_truck
#   4: military_vehicle
#   5: civilian
#   6: soldier
#   7: civilian_vehicle
#   8: military_artillery
#   9: trench
#   10: military_aircraft
#   11: military_warship

# %%
yaml_content = """
path: /content/major_project/military_object_dataset

train: train/images
val: val/images
test: test/images

names:
  0: camouflage_soldier
  1: weapon
  2: military_tank
  3: military_truck
  4: military_vehicle
  5: civilian
  6: soldier
  7: civilian_vehicle
  8: military_artillery
  9: trench
  10: military_aircraft
  11: military_warship
"""

with open("/content/major_project/military_dataset.yaml", "w") as f:
    f.write(yaml_content)

print("YAML fixed for Colab ✅")
# Out:
# YAML fixed for Colab ✅

# %%
# !ls /content/major_project/military_object_dataset/train/images | head
# Out:
# 000065.jpg
# 000066.jpg
# 000067.jpg
# 000068.jpg
# 000069.jpg
# 000070.jpg
# 000071.jpg
# 000072.jpg
# 000073.jpg
# 000074.jpg

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/major_project/v8best.pt")

metrics = model.val(
    data="/content/major_project/military_dataset.yaml",
    plots=True
)
print("Precision:", metrics.box.mp)
print("Recall:", metrics.box.mr)
print("mAP@0.5:", metrics.box.map50)
print("mAP@0.5:0.95:", metrics.box.map)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 576.7±603.7 MB/s, size: 54.5 KB)
# val: Scanning /content/major_project/military_object_dataset/val/labels.cache... 2941 images, 273 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2941/2941 268.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 184/184 2.0s/it 6:04
#                    all       2941       5081      0.528      0.398      0.396      0.247
#     camouflage_soldier        385        510      0.628      0.615      0.631      0.334
#                 weapon        222        358      0.642      0.508      0.505       0.36
#          military_tank        938       1787      0.744      0.789      0.783      0.497
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/major_project/v8best.pt")

print(type(model.model))
print(model.model.__class__.__name__)
# Out:
# <class 'ultralytics.nn.tasks.DetectionModel'>
# DetectionModel
